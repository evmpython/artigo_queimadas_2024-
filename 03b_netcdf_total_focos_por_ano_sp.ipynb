# %% [markdown]
# # Leitura dos dados

# %%
import time

# %%
# %%time
#============================================================================================#
#                                    IMPORTA BIBLIOTECAS
#============================================================================================#
import pandas as pd
import glob
import numpy as np

#============================================================================================#
#                                    DADOS DE 2003-2023
#============================================================================================#
# cria uma tabela (conhecida também com o nome em inglês de "dataframe") vazia
df_2003_a_2023 = pd.DataFrame()

# lista os arquivos mensais do ano atual
files = sorted(glob.glob('output/01_focos_raw/focos_br_ref_*')) # focos_br_ref_2004.zip

# loop de cada arquivo da lista files
for file in files:

    # leitura da tabela
    df0 = pd.read_csv(file, compression='zip')

    # junta a tabela que foi lida com a anterior
    df_2003_a_2023 = pd.concat([df_2003_a_2023, df0], ignore_index=True)

# remove colunas
df_2003_a_2023.drop(['id_bdq','foco_id','pais'], axis=1, inplace=True)

# renomeia coluna
df_2003_a_2023.rename(columns={'data_pas': 'data'}, inplace=True)

# reposiciona as colunas
df_2003_a_2023 = df_2003_a_2023[['data','lat','lon','municipio','estado','bioma']]

#============================================================================================#
#                                    DADOS DE 2024
#============================================================================================#
# cria uma tabela
df_2024 = pd.DataFrame()

# lista os arquivos mensais do ano atual
files = sorted(glob.glob('output/01_focos_raw/focos_mensal_br_*csv')) # focos_mensal_br_202401.csv

# loop de cada arquivo da lista files
for file in files:

    # leitura da tabela
    df0 = pd.read_csv(file, usecols=['lat', 'lon', 'data_hora_gmt', 'satelite', 'municipio', 'estado', 'bioma'])

    # junta a tabela que foi lida com a anterior
    df_2024 = pd.concat([df_2024, df0], ignore_index=True)

# seleciona apenas para MG e para o satélite de referência AQUA_M-T
df_2024 = df_2024[ df_2024['satelite']=='AQUA_M-T' ]

# remove colunas
df_2024.drop(['satelite'], axis=1, inplace=True)

# renomeia coluna
df_2024.rename(columns={'data_hora_gmt': 'data'}, inplace=True)

# reposiciona as colunas
df_2024 = df_2024[['data','lat','lon','municipio','estado','bioma']]

#============================================================================================#
#                         JUNTA OS ARQUIVOS 2003-2023 E 2024
#============================================================================================#
# junta os dataframes
df_total = pd.concat([df_2003_a_2023, df_2024], ignore_index=True)

# transforma a coluna "datahora" para o formato "datetime"
df_total['data'] = pd.to_datetime(df_total['data'])

# seta a coluna "datahora" como o índice da tabela
df_total.set_index('data', inplace=True)

# ordena a tabela pelo índice
df_total.sort_index(inplace=True)

# mostra o dataframe final
df_total
# Out:
# CPU times: total: 1min 2s
# Wall time: 1min 3s
#                           lat       lon    municipio        estado  \
# data
# 2003-01-01 16:04:00 -14.82900 -40.13300   NOVA CANAÃ         BAHIA
# 2003-01-01 16:04:00 -15.62100 -41.66500      BERIZAL  MINAS GERAIS
# 2003-01-01 16:04:00 -15.27600 -41.51400     TREMEDAL         BAHIA
# 2003-01-01 16:05:00 -10.11100 -36.50500  IGREJA NOVA       ALAGOAS
# 2003-01-01 16:05:00 -11.88600 -37.81500    ESPLANADA         BAHIA
# ...                       ...       ...          ...           ...
# 2024-12-31 17:53:00  -0.30758 -51.71391      MAZAGÃO         AMAPÁ
# 2024-12-31 17:53:00  -1.21053 -52.02901     ALMEIRIM          PARÁ
# 2024-12-31 17:53:00  -2.27447 -54.47422     SANTARÉM          PARÁ
# 2024-12-31 17:53:00  -1.61980 -49.83651   CURRALINHO          PARÁ
# 2024-12-31 17:53:00  -1.20924 -52.02020     ALMEIRIM          PARÁ
#
#                               bioma
# data
# 2003-01-01 16:04:00  Mata Atlântica
# 2003-01-01 16:04:00  Mata Atlântica
# 2003-01-01 16:04:00  Mata Atlântica
# 2003-01-01 16:05:00        Caatinga
# 2003-01-01 16:05:00  Mata Atlântica
# ...                             ...
# 2024-12-31 17:53:00        Amazônia
# 2024-12-31 17:53:00        Amazônia
# 2024-12-31 17:53:00        Amazônia
# 2024-12-31 17:53:00        Amazônia
# 2024-12-31 17:53:00        Amazônia
#
# [5108015 rows x 5 columns]

# %% [markdown]
# # Processamento

# %% [markdown]
# ## Função

# %%
# Função que calcula o índice i e j da localização do foco
def index(longitudes_matriz, latitudes_matriz, lon_foco, lat_foco):

    ''' Função para calcular o índice (i e j) do pixel de uma matriz que o relâmpago pertence

    Parâmetros:
               longitudes_matriz (array): array de uma dimensão das longitudes da matriz em graus
               latitudes_matriz (array): array de uma dimensão das latitudes da matriz em graus
               lon_raio (float): valor da longitude do foco em graus
               lat_raio (float): valor da latitude do foco em graus

    Retorna:
            indice_lat_raio (float): índice da latitude (ou seja, da linha) do pixel da matriz que o foco pertence
            indice_lon_raio (float): índice da longitude (ou seja, da coluna) do pixel da matriz que o foco pertence
    '''

    # calcula a diferença entre as lats/lons da matriz e a latitude/longitude do foco
    distancia_lon = (longitudes_matriz - lon_foco)**2
    distancia_lat = (latitudes_matriz - lat_foco)**2

    # índice da longitude e latitude do foco
    indice_lon_foco = np.nonzero(distancia_lon == np.min(distancia_lon))
    indice_lat_foco  = np.nonzero(distancia_lat == np.min(distancia_lat))

    # retorna os valores dos índices calculados
    return indice_lat_foco, indice_lon_foco

# %% [markdown]
# ## Acumula na grade e salva arquivo netcdf do total de focos por ano

# %%
# mostra o dataframe final
df_total
# Out:
#                           lat       lon                 municipio  \
# data
# 2003-01-01 16:04:00 -14.82900 -40.13300                NOVA CANAÃ
# 2003-01-01 16:04:00 -15.62100 -41.66500                   BERIZAL
# 2003-01-01 16:04:00 -15.27600 -41.51400                  TREMEDAL
# 2003-01-01 16:05:00 -10.11100 -36.50500               IGREJA NOVA
# 2003-01-01 16:05:00 -11.88600 -37.81500                 ESPLANADA
# ...                       ...       ...                       ...
# 2024-10-07 18:47:00  -8.71365 -66.89462                    LÁBREA
# 2024-10-07 18:47:00  -8.71499 -66.90406                    LÁBREA
# 2024-10-07 18:47:00  -7.94438 -72.48077           CRUZEIRO DO SUL
# 2024-10-07 18:49:00   1.70215 -69.40170  SÃO GABRIEL DA CACHOEIRA
# 2024-10-07 18:49:00   0.31643 -69.97574  SÃO GABRIEL DA CACHOEIRA
#
#                            estado           bioma
# data
# 2003-01-01 16:04:00         BAHIA  Mata Atlântica
# 2003-01-01 16:04:00  MINAS GERAIS  Mata Atlântica
# 2003-01-01 16:04:00         BAHIA  Mata Atlântica
# 2003-01-01 16:05:00       ALAGOAS        Caatinga
# 2003-01-01 16:05:00         BAHIA  Mata Atlântica
# ...                           ...             ...
# 2024-10-07 18:47:00      AMAZONAS        Amazônia
# 2024-10-07 18:47:00      AMAZONAS        Amazônia
# 2024-10-07 18:47:00          ACRE        Amazônia
# 2024-10-07 18:49:00      AMAZONAS        Amazônia
# 2024-10-07 18:49:00      AMAZONAS        Amazônia
#
# [5048442 rows x 5 columns]

# %%
# selecionando dados de SP
df_total_sp = df_total[df_total['estado'] == 'SÃO PAULO']
df_total_sp
# Out:
#                           lat       lon         municipio     estado  \
# data
# 2003-01-02 16:45:00 -22.55400 -49.22000       PAULISTÂNIA  SÃO PAULO
# 2003-01-02 16:45:00 -22.74400 -49.01200            BOREBI  SÃO PAULO
# 2003-01-02 16:45:00 -22.87500 -50.12100         IBIRAREMA  SÃO PAULO
# 2003-01-02 16:45:00 -22.50900 -50.02300            OCAUÇU  SÃO PAULO
# 2003-01-02 16:45:00 -22.89700 -50.74800          FLORÍNEA  SÃO PAULO
# ...                       ...       ...               ...        ...
# 2024-12-31 17:49:00 -20.52450 -50.79371  PALMEIRA D'OESTE  SÃO PAULO
# 2024-12-31 17:49:00 -20.38414 -48.74170          BARRETOS  SÃO PAULO
# 2024-12-31 17:49:00 -20.70576 -49.14645          GUAPIAÇU  SÃO PAULO
# 2024-12-31 17:49:00 -20.29905 -48.86276          COLÔMBIA  SÃO PAULO
# 2024-12-31 17:49:00 -20.70715 -49.15673          GUAPIAÇU  SÃO PAULO
#
#                               bioma
# data
# 2003-01-02 16:45:00         Cerrado
# 2003-01-02 16:45:00         Cerrado
# 2003-01-02 16:45:00  Mata Atlântica
# 2003-01-02 16:45:00         Cerrado
# 2003-01-02 16:45:00  Mata Atlântica
# ...                             ...
# 2024-12-31 17:49:00  Mata Atlântica
# 2024-12-31 17:49:00         Cerrado
# 2024-12-31 17:49:00         Cerrado
# 2024-12-31 17:49:00         Cerrado
# 2024-12-31 17:49:00         Cerrado
#
# [87732 rows x 5 columns]

# %%
# %%time
# importa bibliotecas
import xarray as xr

# Limites do Brasil
lonmim_BR, lonmax_BR, latmin_BR, latmax_BR = -75.0, -33.0, -35.0, 7.0

# Limites de SP
lonmin_SP, lonmax_SP, latmin_SP, latmax_SP = -53.3, -43.9, -25.4, -19.7

# Espaçamento da grade em graus
delta = 5/100.   # grade com 5 km de resolução espacial

# Montando a grade
lons = np.arange(lonmin_SP, lonmax_SP, delta)
lats = np.arange(latmax_SP, latmin_SP, -delta)

# Quantidade de pontos para longitude e latitude
nlon = len(lons)
nlat = len(lats)

# Loop dos anos
for ano in np.arange(2003,2025):

    print('Processando ===>>>', ano)

    # seleciona o mês
    df_selec = df_total_sp.loc[f'{str(ano)}']

    # gera matriz de raios
    focos_lon, focos_lat = df_selec['lon'].values, df_selec['lat'].values

    # interpolando para ponto de grade
    focos = np.zeros((nlat, nlon))

    # loop em cada longitude e latitude da lista
    for lonfoco, latfoco in zip(focos_lon, focos_lat):

        # função que extrai a qual pixel aquele relâmpago pertence
        lin, col = index(lons, lats, lonfoco, latfoco)

        # soma os relâmpagos por pixel
        focos[lin,col]+=1

    # gera arquivo netcdf
    data_vars = {'focos':(('lat', 'lon'), focos, {'units': 'ocorrências/400km²', 'long_name':'Focos de Calor'})}
    coords = {'lat': lats, 'lon': lons, 'time': pd.to_datetime(f'{str(ano)}-12')}
    ds = xr.Dataset(data_vars=data_vars, coords=coords)
    ds.to_netcdf(f'output/03_netcdf_focos_por_ano/sp_5km/focos_anual_sp_5km_AQUA_{ano}.nc')

    print('Máximo por pixel', np.max(focos), '\n', 'Soma total', np.sum(focos), '\n')
# Out:
# Processando ===>>> 2003
# Máximo por pixel 16.0
#  Soma total 5597.0
#
# Processando ===>>> 2004
# Máximo por pixel 14.0
#  Soma total 4333.0
#
# Processando ===>>> 2005
# Máximo por pixel 14.0
#  Soma total 3832.0
#
# Processando ===>>> 2006
# Máximo por pixel 12.0
#  Soma total 5367.0
#
# Processando ===>>> 2007
# Máximo por pixel 20.0
#  Soma total 4476.0
#
# Processando ===>>> 2008
# Máximo por pixel 13.0
#  Soma total 2796.0
#
# Processando ===>>> 2009
# Máximo por pixel 18.0
#  Soma total 1763.0
#
# Processando ===>>> 2010
# Máximo por pixel 29.0
#  Soma total 7291.0
#
# Processando ===>>> 2011
# Máximo por pixel 18.0
#  Soma total 4183.0
#
# Processando ===>>> 2012
# Máximo por pixel 13.0
#  Soma total 2662.0
#
# Processando ===>>> 2013
# Máximo por pixel 14.0
#  Soma total 2388.0
#
# Processando ===>>> 2014
# Máximo por pixel 17.0
#  Soma total 4484.0
#
# Processando ===>>> 2015
# Máximo por pixel 10.0
#  Soma total 1808.0
#
# Processando ===>>> 2016
# Máximo por pixel 11.0
#  Soma total 3186.0
#
# Processando ===>>> 2017
# Máximo por pixel 18.0
#  Soma total 3902.0
#
# Processando ===>>> 2018
# Máximo por pixel 18.0
#  Soma total 3019.0
#
# Processando ===>>> 2019
# Máximo por pixel 23.0
#  Soma total 3074.0
#
# Processando ===>>> 2020
# Máximo por pixel 22.0
#  Soma total 6123.0
#
# Processando ===>>> 2021
# Máximo por pixel 30.0
#  Soma total 5469.0
#
# Processando ===>>> 2022
# Máximo por pixel 12.0
#  Soma total 1599.0
#
# Processando ===>>> 2023
# Máximo por pixel 16.0
#  Soma total 1666.0
#
# Processando ===>>> 2024
# Máximo por pixel 32.0
#  Soma total 8714.0
#
# CPU times: total: 8.22 s
# Wall time: 8.43 s

# %%
ds = xr.open_dataset(f'output/03_netcdf_focos_por_ano/sp_5km/focos_anual_sp_5km_AQUA_2024.nc')
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 114, lon: 188)
# Coordinates:
#   * lat      (lat) float64 -19.7 -19.75 -19.8 -19.85 ... -25.25 -25.3 -25.35
#   * lon      (lon) float64 -53.3 -53.25 -53.2 -53.15 ... -44.05 -44.0 -43.95
#     time     datetime64[ns] ...
# Data variables:
#     focos    (lat, lon) float64 ...

# %%
ds['focos'].plot(cmap='jet')
